# %% [markdown]
# <a href="https://colab.research.google.com/github/Judy-Choi/Tensorflow_Certificate/blob/main/5_beans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Goal Metric
# - val_loss : 0.28
# - val_acc : -

# %% [markdown]
# # 정답 코드 (CNN) - 0.22838

# %%
# ==============================================================================
# There are 5 questions in this exam with increasing difficulty from 1-5.
# Please note that the weight of the grade for the question is relative to its
# difficulty. So your Category 1 question will score significantly
# less than your Category 5 question.
#
# WARNING: Do not use lambda layers in your model, they are not supported
# on the grading infrastructure. You do not need them to solve the question.
#
# You must use the Submit and Test button to submit your model
# at least once in this category before you finally submit your exam,
# otherwise you will score zero for this category.
# ==============================================================================
#
# COMPUTER VISION WITH CNNs
#
# Create and train a classifier to classify images between three categories
# of beans using the beans dataset.
# ==============================================================================
# ABOUT THE DATASET
#
# Beans dataset has images belonging to 3 classes as follows:
# 2 disease classes (Angular leaf spot, bean rust)
# 1 healthy class (healthy).
# The images are of different sizes and have 3 channels.
# ==============================================================================
#
# INSTRUCTIONS
#
# We have already divided the data for training and validation.
#
# Complete the code in following functions:
# 1. preprocess()
# 2. solution_model()
#
# Your code will fail to be graded if the following criteria are not met:
# 1. The input shape of your model must be (300,300,3), because the testing
#    infrastructure expects inputs according to this specification. You must
#    resize all the images in the dataset to this size while pre-processing
#    the dataset.
# 2. The last layer of your model must be a Dense layer with 3 neurons
#    activated by softmax since this dataset has 3 classes.
#
# HINT: Your neural network must have a validation accuracy of approximately
# 0.75 or above on the normalized validation dataset for top marks.
#


import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Use this constant wherever necessary
IMG_SIZE = 300

# This function normalizes and resizes the images.

# COMPLETE THE CODE IN THIS FUNCTION
def preprocess(image, label):
    # RESIZE YOUR IMAGES HERE (HINT: After resizing the shape of the images
    # should be (300, 300, 3).
    # NORMALIZE YOUR IMAGES HERE (HINT: Rescale by 1/.255))
  
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.resize(image, size=(300, 300))
    return image, label


# This function loads the data, normalizes and resizes the images, splits it into
# train and validation sets, defines the model, compiles it and finally
# trains the model. The trained model is returned from this function.

# COMPLETE THE CODE IN THIS FUNCTION.
def solution_model():
    # Loads and splits the data into training and validation splits using tfds.
    (ds_train, ds_validation), ds_info = tfds.load(
        name='beans',
        split=['train', 'validation'],
        as_supervised=True,
        with_info=True)
 
    BATCH_SIZE = 32 # YOUR CODE HERE

    # Resizes and normalizes train and validation datasets using the
    # preprocess() function.
    # Also makes other calls, as evident from the code, to prepare them for
    # training.
    ds_train = ds_train.map(preprocess).cache().shuffle(
        ds_info.splits['train'].num_examples).batch(BATCH_SIZE).prefetch(
        tf.data.experimental.AUTOTUNE)
    ds_validation = ds_validation.map(preprocess).batch(BATCH_SIZE).cache(

    ).prefetch(tf.data.experimental.AUTOTUNE)

    # Code to define the model
    model = tf.keras.models.Sequential([

        # ADD LAYERS OF THE MODEL HERE
    Conv2D(32, (3, 3), activation='relu', input_shape=(300, 300, 3), padding='same'),
    MaxPooling2D(2, 2), 
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(2, 2), 
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(2, 2), 
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(2, 2), 
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(2, 2), 
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(2, 2), 
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(2, 2), 
    Flatten(), 
    Dense(64, activation='relu'), 
    Dropout(0.2),
    Dense(32, activation='relu'), 


    # If you don't adhere to the instructions in the following comments,
    # tests will fail to grade your model:
    # The input layer of your model must have an input shape of
    # (300,300,3).
    # Make sure that your last layer has 3 (number of classes) neurons
    # activated by softmax.
    tf.keras.layers.Dense(3, activation='softmax'),
    ])

    # Code to compile and train the model
    model.compile(
        # YOUR CODE HERE
        loss = 'sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy']
    )
       
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    checkpoint_path = "checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path,
        save_weights_only=True,
        save_best_only = True,
        monitor='val_loss',
        verbose=1)
    
    model.fit(ds_train, 
            validation_data=(ds_validation),
            epochs=100, 
            callbacks=[checkpoint, early_stopping])
    model.load_weights(checkpoint_path)                      

    return model


# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, your saved .h5 model will
# be sent to the testing infrastructure for scoring
# and the score will be returned to you.
if __name__ == '__main__':
    model = solution_model()
    model.save("beans-cnn.h5")
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/beans/0.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/beans/0.1.0.incomplete8QWDRH/beans-train.tfrecord*...:   0%|          | 0/…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/beans/0.1.0.incomplete8QWDRH/beans-validation.tfrecord*...:   0%|         …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/beans/0.1.0.incomplete8QWDRH/beans-test.tfrecord*...:   0%|          | 0/1…
# Dataset beans downloaded and prepared to /root/tensorflow_datasets/beans/0.1.0. Subsequent calls will reuse this data.
# Epoch 1/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0713 - accuracy: 0.4110
# Epoch 1: val_loss improved from inf to 1.00080, saving model to checkpoint.ckpt
# 33/33 [==============================] - 25s 128ms/step - loss: 1.0713 - accuracy: 0.4110 - val_loss: 1.0008 - val_accuracy: 0.4962
# Epoch 2/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.9596 - accuracy: 0.5225
# Epoch 2: val_loss improved from 1.00080 to 0.84576, saving model to checkpoint.ckpt
# 33/33 [==============================] - 2s 71ms/step - loss: 0.9598 - accuracy: 0.5222 - val_loss: 0.8458 - val_accuracy: 0.5940
# Epoch 3/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.8626 - accuracy: 0.5879
# Epoch 3: val_loss improved from 0.84576 to 0.73799, saving model to checkpoint.ckpt
# 33/33 [==============================] - 3s 79ms/step - loss: 0.8656 - accuracy: 0.5870 - val_loss: 0.7380 - val_accuracy: 0.6541
# Epoch 4/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.8123 - accuracy: 0.6221
# Epoch 4: val_loss improved from 0.73799 to 0.73440, saving model to checkpoint.ckpt
# 33/33 [==============================] - 2s 70ms/step - loss: 0.8122 - accuracy: 0.6219 - val_loss: 0.7344 - val_accuracy: 0.6617
# Epoch 5/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.7023 - accuracy: 0.6855
# Epoch 5: val_loss improved from 0.73440 to 0.62652, saving model to checkpoint.ckpt
# 33/33 [==============================] - 2s 69ms/step - loss: 0.7013 - accuracy: 0.6867 - val_loss: 0.6265 - val_accuracy: 0.7368
# Epoch 6/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.6209 - accuracy: 0.7119
# Epoch 6: val_loss improved from 0.62652 to 0.55060, saving model to checkpoint.ckpt
# 33/33 [==============================] - 3s 75ms/step - loss: 0.6181 - accuracy: 0.7128 - val_loss: 0.5506 - val_accuracy: 0.7444
# Epoch 7/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.5157 - accuracy: 0.7773
# Epoch 7: val_loss did not improve from 0.55060
# 33/33 [==============================] - 2s 70ms/step - loss: 0.5168 - accuracy: 0.7766 - val_loss: 0.6092 - val_accuracy: 0.7444
# Epoch 8/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.4948 - accuracy: 0.7939
# Epoch 8: val_loss improved from 0.55060 to 0.43749, saving model to checkpoint.ckpt
# 33/33 [==============================] - 3s 82ms/step - loss: 0.4964 - accuracy: 0.7940 - val_loss: 0.4375 - val_accuracy: 0.8120
# Epoch 9/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.4100 - accuracy: 0.8213
# Epoch 9: val_loss improved from 0.43749 to 0.34229, saving model to checkpoint.ckpt
# 33/33 [==============================] - 2s 72ms/step - loss: 0.4095 - accuracy: 0.8221 - val_loss: 0.3423 - val_accuracy: 0.8421
# Epoch 10/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.3614 - accuracy: 0.8369
# Epoch 10: val_loss did not improve from 0.34229
# 33/33 [==============================] - 2s 67ms/step - loss: 0.3594 - accuracy: 0.8385 - val_loss: 0.4030 - val_accuracy: 0.8571
# Epoch 11/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.4042 - accuracy: 0.8418
# Epoch 11: val_loss improved from 0.34229 to 0.31689, saving model to checkpoint.ckpt
# 33/33 [==============================] - 2s 71ms/step - loss: 0.4039 - accuracy: 0.8414 - val_loss: 0.3169 - val_accuracy: 0.8797
# Epoch 12/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.3109 - accuracy: 0.8789
# Epoch 12: val_loss did not improve from 0.31689
# 33/33 [==============================] - 3s 78ms/step - loss: 0.3160 - accuracy: 0.8762 - val_loss: 0.3480 - val_accuracy: 0.8421
# Epoch 13/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.3316 - accuracy: 0.8721
# Epoch 13: val_loss did not improve from 0.31689
# 33/33 [==============================] - 2s 67ms/step - loss: 0.3302 - accuracy: 0.8723 - val_loss: 0.3237 - val_accuracy: 0.8872
# Epoch 14/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.2751 - accuracy: 0.8984
# Epoch 14: val_loss improved from 0.31689 to 0.29368, saving model to checkpoint.ckpt
# 33/33 [==============================] - 2s 70ms/step - loss: 0.2742 - accuracy: 0.8985 - val_loss: 0.2937 - val_accuracy: 0.8872
# Epoch 15/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.2184 - accuracy: 0.9023
# Epoch 15: val_loss improved from 0.29368 to 0.24929, saving model to checkpoint.ckpt
# 33/33 [==============================] - 2s 70ms/step - loss: 0.2180 - accuracy: 0.9023 - val_loss: 0.2493 - val_accuracy: 0.9098
# Epoch 16/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.2042 - accuracy: 0.9209
# Epoch 16: val_loss improved from 0.24929 to 0.22838, saving model to checkpoint.ckpt
# 33/33 [==============================] - 2s 71ms/step - loss: 0.2026 - accuracy: 0.9217 - val_loss: 0.2284 - val_accuracy: 0.9098
# Epoch 17/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.1774 - accuracy: 0.9297
# Epoch 17: val_loss did not improve from 0.22838
# 33/33 [==============================] - 3s 78ms/step - loss: 0.1779 - accuracy: 0.9294 - val_loss: 0.2413 - val_accuracy: 0.9173
# Epoch 18/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.1797 - accuracy: 0.9268
# Epoch 18: val_loss did not improve from 0.22838
# 33/33 [==============================] - 2s 67ms/step - loss: 0.1802 - accuracy: 0.9265 - val_loss: 0.4226 - val_accuracy: 0.8346
# Epoch 19/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.1814 - accuracy: 0.9268
# Epoch 19: val_loss did not improve from 0.22838
# 33/33 [==============================] - 2s 68ms/step - loss: 0.1804 - accuracy: 0.9275 - val_loss: 0.2624 - val_accuracy: 0.8947
# Epoch 20/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.1059 - accuracy: 0.9629
# Epoch 20: val_loss did not improve from 0.22838
# 33/33 [==============================] - 2s 70ms/step - loss: 0.1070 - accuracy: 0.9623 - val_loss: 0.2459 - val_accuracy: 0.9098
# Epoch 21/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.0865 - accuracy: 0.9697
# Epoch 21: val_loss did not improve from 0.22838
# 33/33 [==============================] - 2s 68ms/step - loss: 0.0873 - accuracy: 0.9691 - val_loss: 0.2897 - val_accuracy: 0.8947
# Epoch 22/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.1257 - accuracy: 0.9453
# Epoch 22: val_loss did not improve from 0.22838
# 33/33 [==============================] - 3s 78ms/step - loss: 0.1246 - accuracy: 0.9458 - val_loss: 0.2787 - val_accuracy: 0.9023
# Epoch 23/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.0627 - accuracy: 0.9756
# Epoch 23: val_loss did not improve from 0.22838
# 33/33 [==============================] - 2s 67ms/step - loss: 0.0621 - accuracy: 0.9758 - val_loss: 0.3422 - val_accuracy: 0.9023
# Epoch 24/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.0684 - accuracy: 0.9707
# Epoch 24: val_loss did not improve from 0.22838
# 33/33 [==============================] - 2s 68ms/step - loss: 0.0682 - accuracy: 0.9710 - val_loss: 0.3977 - val_accuracy: 0.8872
# Epoch 25/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.0918 - accuracy: 0.9629
# Epoch 25: val_loss did not improve from 0.22838
# 33/33 [==============================] - 2s 67ms/step - loss: 0.0911 - accuracy: 0.9632 - val_loss: 0.2719 - val_accuracy: 0.9173
# Epoch 26/100
# 32/33 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9893
# Epoch 26: val_loss did not improve from 0.22838
# 33/33 [==============================] - 2s 68ms/step - loss: 0.0338 - accuracy: 0.9894 - val_loss: 0.5099 - val_accuracy: 0.9098

# %% [markdown]
# # Homework 1 : 직접 코딩 (CNN) - 0.47305

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Use this constant wherever necessary
IMG_SIZE = 300

# This function normalizes and resizes the images.

# COMPLETE THE CODE IN THIS FUNCTION
def preprocess(image, label):
    # RESIZE YOUR IMAGES HERE (HINT: After resizing the shape of the images
    # should be (300, 300, 3).
    # NORMALIZE YOUR IMAGES HERE (HINT: Rescale by 1/.255))
  
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.resize(image, size=(300, 300))
    return image, label


# This function loads the data, normalizes and resizes the images, splits it into
# train and validation sets, defines the model, compiles it and finally
# trains the model. The trained model is returned from this function.

# COMPLETE THE CODE IN THIS FUNCTION.
def solution_model():
    # Loads and splits the data into training and validation splits using tfds.
    (ds_train, ds_validation), ds_info = tfds.load(
        name='beans',
        split=['train', 'validation'],
        as_supervised=True,
        with_info=True)
 
    BATCH_SIZE = 32 # YOUR CODE HERE

    # Resizes and normalizes train and validation datasets using the
    # preprocess() function.
    # Also makes other calls, as evident from the code, to prepare them for
    # training.
    ds_train = ds_train.map(preprocess).cache().shuffle(
        ds_info.splits['train'].num_examples).batch(BATCH_SIZE).prefetch(
        tf.data.experimental.AUTOTUNE)
    ds_validation = ds_validation.map(preprocess).batch(BATCH_SIZE).cache(

    ).prefetch(tf.data.experimental.AUTOTUNE)

    # Code to define the model
    model = tf.keras.models.Sequential([

    # Layer 수 감소, 필터 수 증가
    Conv2D(32, (3, 3), activation='relu', input_shape=(300, 300, 3), padding='same'),
    MaxPooling2D(2, 2), 
    Dropout(0.2),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(2, 2), 
    Dropout(0.2),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(2, 2), 
    Dropout(0.2),

    Flatten(), 
    Dense(64, activation='relu'), 
    Dropout(0.2),
    Dense(32, activation='relu'), 
    Dense(3, activation='softmax'),
    ])

    # Code to compile and train the model
    model.compile(
        # YOUR CODE HERE
        loss = 'sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy']
    )
       
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    checkpoint_path = "checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path,
        save_weights_only=True,
        save_best_only = True,
        monitor='val_loss',
        verbose=1)
    
    model.fit(ds_train, 
            validation_data=(ds_validation),
            epochs=100, 
            callbacks=[checkpoint, early_stopping])
    model.load_weights(checkpoint_path)                      

    return model


# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, your saved .h5 model will
# be sent to the testing infrastructure for scoring
# and the score will be returned to you.
if __name__ == '__main__':
    model = solution_model()
    model.save("beans-cnn.h5")
# Out:
# Epoch 1/100
# 33/33 [==============================] - ETA: 0s - loss: 1.2677 - accuracy: 0.3762
# Epoch 1: val_loss improved from inf to 1.07749, saving model to checkpoint.ckpt
# 33/33 [==============================] - 15s 234ms/step - loss: 1.2677 - accuracy: 0.3762 - val_loss: 1.0775 - val_accuracy: 0.4511
# Epoch 2/100
# 33/33 [==============================] - ETA: 0s - loss: 0.9572 - accuracy: 0.5484
# Epoch 2: val_loss improved from 1.07749 to 0.81236, saving model to checkpoint.ckpt
# 33/33 [==============================] - 6s 181ms/step - loss: 0.9572 - accuracy: 0.5484 - val_loss: 0.8124 - val_accuracy: 0.6466
# Epoch 3/100
# 33/33 [==============================] - ETA: 0s - loss: 0.8712 - accuracy: 0.5880
# Epoch 3: val_loss did not improve from 0.81236
# 33/33 [==============================] - 6s 169ms/step - loss: 0.8712 - accuracy: 0.5880 - val_loss: 0.8281 - val_accuracy: 0.6767
# Epoch 4/100
# 33/33 [==============================] - ETA: 0s - loss: 0.8480 - accuracy: 0.6335
# Epoch 4: val_loss improved from 0.81236 to 0.68718, saving model to checkpoint.ckpt
# 33/33 [==============================] - 6s 186ms/step - loss: 0.8480 - accuracy: 0.6335 - val_loss: 0.6872 - val_accuracy: 0.6617
# Epoch 5/100
# 33/33 [==============================] - ETA: 0s - loss: 0.7311 - accuracy: 0.6596
# Epoch 5: val_loss did not improve from 0.68718
# 33/33 [==============================] - 6s 169ms/step - loss: 0.7311 - accuracy: 0.6596 - val_loss: 0.6954 - val_accuracy: 0.6992
# Epoch 6/100
# 33/33 [==============================] - ETA: 0s - loss: 0.6865 - accuracy: 0.7031
# Epoch 6: val_loss improved from 0.68718 to 0.62370, saving model to checkpoint.ckpt
# 33/33 [==============================] - 6s 183ms/step - loss: 0.6865 - accuracy: 0.7031 - val_loss: 0.6237 - val_accuracy: 0.7744
# Epoch 7/100
# 33/33 [==============================] - ETA: 0s - loss: 0.6785 - accuracy: 0.7273
# Epoch 7: val_loss improved from 0.62370 to 0.61998, saving model to checkpoint.ckpt
# 33/33 [==============================] - 6s 188ms/step - loss: 0.6785 - accuracy: 0.7273 - val_loss: 0.6200 - val_accuracy: 0.7218
# Epoch 8/100
# 33/33 [==============================] - ETA: 0s - loss: 0.5806 - accuracy: 0.7485
# Epoch 8: val_loss did not improve from 0.61998
# 33/33 [==============================] - 6s 170ms/step - loss: 0.5806 - accuracy: 0.7485 - val_loss: 0.6836 - val_accuracy: 0.7068
# Epoch 9/100
# 33/33 [==============================] - ETA: 0s - loss: 0.5777 - accuracy: 0.7573
# Epoch 9: val_loss improved from 0.61998 to 0.53023, saving model to checkpoint.ckpt
# 33/33 [==============================] - 6s 184ms/step - loss: 0.5777 - accuracy: 0.7573 - val_loss: 0.5302 - val_accuracy: 0.7594
# Epoch 10/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4728 - accuracy: 0.8056
# Epoch 10: val_loss did not improve from 0.53023
# 33/33 [==============================] - 6s 167ms/step - loss: 0.4728 - accuracy: 0.8056 - val_loss: 0.5874 - val_accuracy: 0.7594
# Epoch 11/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3991 - accuracy: 0.8375
# Epoch 11: val_loss did not improve from 0.53023
# 33/33 [==============================] - 6s 167ms/step - loss: 0.3991 - accuracy: 0.8375 - val_loss: 0.5447 - val_accuracy: 0.7744
# Epoch 12/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3677 - accuracy: 0.8501
# Epoch 12: val_loss improved from 0.53023 to 0.48108, saving model to checkpoint.ckpt
# 33/33 [==============================] - 6s 187ms/step - loss: 0.3677 - accuracy: 0.8501 - val_loss: 0.4811 - val_accuracy: 0.7669
# Epoch 13/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.8665
# Epoch 13: val_loss improved from 0.48108 to 0.47305, saving model to checkpoint.ckpt
# 33/33 [==============================] - 6s 184ms/step - loss: 0.3366 - accuracy: 0.8665 - val_loss: 0.4731 - val_accuracy: 0.8195
# Epoch 14/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2764 - accuracy: 0.8888
# Epoch 14: val_loss did not improve from 0.47305
# 33/33 [==============================] - 6s 168ms/step - loss: 0.2764 - accuracy: 0.8888 - val_loss: 0.5247 - val_accuracy: 0.7744
# Epoch 15/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.9043
# Epoch 15: val_loss did not improve from 0.47305
# 33/33 [==============================] - 6s 172ms/step - loss: 0.2767 - accuracy: 0.9043 - val_loss: 0.4999 - val_accuracy: 0.8045
# Epoch 16/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9139
# Epoch 16: val_loss did not improve from 0.47305
# 33/33 [==============================] - 6s 167ms/step - loss: 0.1971 - accuracy: 0.9139 - val_loss: 0.6374 - val_accuracy: 0.7669
# Epoch 17/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2167 - accuracy: 0.9197
# Epoch 17: val_loss did not improve from 0.47305
# 33/33 [==============================] - 6s 174ms/step - loss: 0.2167 - accuracy: 0.9197 - val_loss: 0.5350 - val_accuracy: 0.7293
# Epoch 18/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1563 - accuracy: 0.9381
# Epoch 18: val_loss did not improve from 0.47305
# 33/33 [==============================] - 6s 167ms/step - loss: 0.1563 - accuracy: 0.9381 - val_loss: 0.6402 - val_accuracy: 0.7820
# Epoch 19/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9555
# Epoch 19: val_loss did not improve from 0.47305
# 33/33 [==============================] - 6s 172ms/step - loss: 0.1255 - accuracy: 0.9555 - val_loss: 0.7503 - val_accuracy: 0.7744
# Epoch 20/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9565
# Epoch 20: val_loss did not improve from 0.47305
# 33/33 [==============================] - 6s 170ms/step - loss: 0.1165 - accuracy: 0.9565 - val_loss: 0.5585 - val_accuracy: 0.8195
# Epoch 21/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1225 - accuracy: 0.9526
# Epoch 21: val_loss did not improve from 0.47305
# 33/33 [==============================] - 6s 169ms/step - loss: 0.1225 - accuracy: 0.9526 - val_loss: 0.5827 - val_accuracy: 0.8045
# Epoch 22/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1636 - accuracy: 0.9487
# Epoch 22: val_loss did not improve from 0.47305
# 33/33 [==============================] - 6s 168ms/step - loss: 0.1636 - accuracy: 0.9487 - val_loss: 0.5793 - val_accuracy: 0.8195
# Epoch 23/100
# 33/33 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9642
# Epoch 23: val_loss did not improve from 0.47305
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0939 - accuracy: 0.9642 - val_loss: 0.9367 - val_accuracy: 0.7669

# %% [markdown]
# # Homework 2 : 직접 코딩 (Transfer Learning - VGG16) - 0.44703

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.applications import VGG16

# Use this constant wherever necessary
IMG_SIZE = 300

# This function normalizes and resizes the images.

# COMPLETE THE CODE IN THIS FUNCTION
def preprocess(image, label):
    # RESIZE YOUR IMAGES HERE (HINT: After resizing the shape of the images
    # should be (300, 300, 3).
    # NORMALIZE YOUR IMAGES HERE (HINT: Rescale by 1/.255))
  
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.resize(image, size=(300, 300))
    return image, label


# COMPLETE THE CODE IN THIS FUNCTION.
def solution_model():
    # Loads and splits the data into training and validation splits using tfds.
    (ds_train, ds_validation), ds_info = tfds.load(
        name='beans',
        split=['train', 'validation'],
        as_supervised=True,
        with_info=True)
 
    BATCH_SIZE = 32 # YOUR CODE HERE

    # Resizes and normalizes train and validation datasets using the
    # preprocess() function.
    # Also makes other calls, as evident from the code, to prepare them for
    # training.
    ds_train = ds_train.map(preprocess).cache().shuffle(
        ds_info.splits['train'].num_examples).batch(BATCH_SIZE).prefetch(
        tf.data.experimental.AUTOTUNE)
    ds_validation = ds_validation.map(preprocess).batch(BATCH_SIZE).cache(

    ).prefetch(tf.data.experimental.AUTOTUNE)

    # Code to define the model
    transfer_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    transfer_model.trainable=False

    model_tr = Sequential([
        transfer_model, 
        Flatten(), 
        # Layer 추가
        Flatten(), 
        Dense(64, activation='relu'), 
        Dropout(0.2),
        Dense(32, activation='relu'), 
        Dense(3, activation='softmax'),
    ])

    # Code to compile and train the model
    model.compile(
        # YOUR CODE HERE
        loss = 'sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy']
    )
       
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    checkpoint_path = "checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path,
        save_weights_only=True,
        save_best_only = True,
        monitor='val_loss',
        verbose=1)
    
    model.fit(ds_train, 
            validation_data=(ds_validation),
            epochs=100, 
            callbacks=[checkpoint, early_stopping])
    model.load_weights(checkpoint_path)                      

    return model


# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, your saved .h5 model will
# be sent to the testing infrastructure for scoring
# and the score will be returned to you.
if __name__ == '__main__':
    model = solution_model()
    model.save("beans-cnn.h5")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Epoch 1/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3371 - accuracy: 0.8714
# Epoch 1: val_loss improved from inf to 0.45623, saving model to checkpoint.ckpt
# 33/33 [==============================] - 12s 204ms/step - loss: 0.3371 - accuracy: 0.8714 - val_loss: 0.4562 - val_accuracy: 0.8195
# Epoch 2/100
# 33/33 [==============================] - ETA: 0s - loss: 0.2295 - accuracy: 0.9110
# Epoch 2: val_loss did not improve from 0.45623
# 33/33 [==============================] - 6s 167ms/step - loss: 0.2295 - accuracy: 0.9110 - val_loss: 0.4595 - val_accuracy: 0.7895
# Epoch 3/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1939 - accuracy: 0.9236
# Epoch 3: val_loss improved from 0.45623 to 0.44703, saving model to checkpoint.ckpt
# 33/33 [==============================] - 6s 180ms/step - loss: 0.1939 - accuracy: 0.9236 - val_loss: 0.4470 - val_accuracy: 0.8120
# Epoch 4/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9275
# Epoch 4: val_loss did not improve from 0.44703
# 33/33 [==============================] - 6s 169ms/step - loss: 0.1720 - accuracy: 0.9275 - val_loss: 0.5719 - val_accuracy: 0.8120
# Epoch 5/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1469 - accuracy: 0.9449
# Epoch 5: val_loss did not improve from 0.44703
# 33/33 [==============================] - 6s 168ms/step - loss: 0.1469 - accuracy: 0.9449 - val_loss: 0.4648 - val_accuracy: 0.8120
# Epoch 6/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9603
# Epoch 6: val_loss did not improve from 0.44703
# 33/33 [==============================] - 6s 169ms/step - loss: 0.1085 - accuracy: 0.9603 - val_loss: 0.5439 - val_accuracy: 0.7970
# Epoch 7/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1354 - accuracy: 0.9468
# Epoch 7: val_loss did not improve from 0.44703
# 33/33 [==============================] - 6s 185ms/step - loss: 0.1354 - accuracy: 0.9468 - val_loss: 0.8171 - val_accuracy: 0.7519
# Epoch 8/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1563 - accuracy: 0.9449
# Epoch 8: val_loss did not improve from 0.44703
# 33/33 [==============================] - 6s 175ms/step - loss: 0.1563 - accuracy: 0.9449 - val_loss: 0.7325 - val_accuracy: 0.7820
# Epoch 9/100
# 33/33 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9681
# Epoch 9: val_loss did not improve from 0.44703
# 33/33 [==============================] - 6s 169ms/step - loss: 0.0883 - accuracy: 0.9681 - val_loss: 0.8297 - val_accuracy: 0.7744
# Epoch 10/100
# 33/33 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9700
# Epoch 10: val_loss did not improve from 0.44703
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0681 - accuracy: 0.9700 - val_loss: 1.0295 - val_accuracy: 0.8120
# Epoch 11/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1139 - accuracy: 0.9536
# Epoch 11: val_loss did not improve from 0.44703
# 33/33 [==============================] - 6s 168ms/step - loss: 0.1139 - accuracy: 0.9536 - val_loss: 0.7267 - val_accuracy: 0.7820
# Epoch 12/100
# 33/33 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9729
# Epoch 12: val_loss did not improve from 0.44703
# 33/33 [==============================] - 6s 171ms/step - loss: 0.0731 - accuracy: 0.9729 - val_loss: 0.6634 - val_accuracy: 0.7970
# Epoch 13/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.9526
# Epoch 13: val_loss did not improve from 0.44703
# 33/33 [==============================] - 6s 168ms/step - loss: 0.1202 - accuracy: 0.9526 - val_loss: 0.7432 - val_accuracy: 0.7820

# %% [markdown]
# # Homework 3 : ChatGPT(CNN) - 1.58812
#
# 다음 코드를 최적화해 줘,
# 단, 다음 조건을 적용해 줘
# Use dropout
# Use batch normalization
# Use checkpoint with save best only, and save weight only and verbose = 1
# Use early stopping with patience = 10
# Use reduce learning rate on plateau
# set verbose = 1
# Set epochs = 50
# do not use data augmentation
# Use other methods to make val loss value lower.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Use this constant wherever necessary
IMG_SIZE = 300

# This function normalizes and resizes the images.

# COMPLETE THE CODE IN THIS FUNCTION
def preprocess(image, label):
    # RESIZE YOUR IMAGES HERE (HINT: After resizing the shape of the images
    # should be (300, 300, 3).
    # NORMALIZE YOUR IMAGES HERE (HINT: Rescale by 1/.255))
  
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.resize(image, size=(300, 300))
    return image, label


# This function loads the data, normalizes and resizes the images, splits it into
# train and validation sets, defines the model, compiles it and finally
# trains the model. The trained model is returned from this function.

# COMPLETE THE CODE IN THIS FUNCTION.
def solution_model():
    # Loads and splits the data into training and validation splits using tfds.
    (ds_train, ds_validation), ds_info = tfds.load(
        name='beans',
        split=['train', 'validation'],
        as_supervised=True,
        with_info=True)
 
    BATCH_SIZE = 32 # YOUR CODE HERE

    # Resizes and normalizes train and validation datasets using the
    # preprocess() function.
    # Also makes other calls, as evident from the code, to prepare them for
    # training.
    ds_train = ds_train.map(preprocess).cache().shuffle(
        ds_info.splits['train'].num_examples).batch(BATCH_SIZE).prefetch(
        tf.data.experimental.AUTOTUNE)
    ds_validation = ds_validation.map(preprocess).batch(BATCH_SIZE).cache(

    ).prefetch(tf.data.experimental.AUTOTUNE)

    # Code to define the model
    model = Sequential([
    Conv2D(32, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(32, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),
    Dropout(0.25),
    Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(64, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

    # Code to compile and train the model
    model.compile(
        # YOUR CODE HERE
        loss = 'sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy']
    )
       
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    checkpoint_path = "checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path,
        save_weights_only=True,
        save_best_only = True,
        monitor='val_loss',
        verbose=1)
    
    # Define the callback for reducing learning rate on plateau
    reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, verbose=1)    
    
    model.fit(ds_train, 
            validation_data=(ds_validation),
            epochs=100, 
            callbacks=[checkpoint, early_stopping, reduce_lr])
    model.load_weights(checkpoint_path)                      

    return model


# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, your saved .h5 model will
# be sent to the testing infrastructure for scoring
# and the score will be returned to you.
if __name__ == '__main__':
    model = solution_model()
    model.save("(ChatGPT) beans-cnn.h5")
# Out:
# Epoch 1/100
# 33/33 [==============================] - ETA: 0s - loss: 1.1027 - accuracy: 0.6383
# Epoch 1: val_loss improved from inf to 2.43341, saving model to checkpoint.ckpt
# 33/33 [==============================] - 36s 780ms/step - loss: 1.1027 - accuracy: 0.6383 - val_loss: 2.4334 - val_accuracy: 0.3308 - lr: 0.0010
# Epoch 2/100
# 33/33 [==============================] - ETA: 0s - loss: 0.8307 - accuracy: 0.6934
# Epoch 2: val_loss improved from 2.43341 to 1.58812, saving model to checkpoint.ckpt
# 33/33 [==============================] - 23s 713ms/step - loss: 0.8307 - accuracy: 0.6934 - val_loss: 1.5881 - val_accuracy: 0.4511 - lr: 0.0010
# Epoch 3/100
# 33/33 [==============================] - ETA: 0s - loss: 0.7137 - accuracy: 0.7195
# Epoch 3: val_loss did not improve from 1.58812
# 33/33 [==============================] - 12s 368ms/step - loss: 0.7137 - accuracy: 0.7195 - val_loss: 1.7390 - val_accuracy: 0.3308 - lr: 0.0010
# Epoch 4/100
# 33/33 [==============================] - ETA: 0s - loss: 0.6091 - accuracy: 0.7650
# Epoch 4: val_loss did not improve from 1.58812
# 33/33 [==============================] - 12s 369ms/step - loss: 0.6091 - accuracy: 0.7650 - val_loss: 2.4708 - val_accuracy: 0.3308 - lr: 0.0010
# Epoch 5/100
# 33/33 [==============================] - ETA: 0s - loss: 0.4466 - accuracy: 0.8327
# Epoch 5: val_loss did not improve from 1.58812
# 33/33 [==============================] - 12s 375ms/step - loss: 0.4466 - accuracy: 0.8327 - val_loss: 2.5608 - val_accuracy: 0.3308 - lr: 0.0010
# Epoch 6/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3799 - accuracy: 0.8501
# Epoch 6: val_loss did not improve from 1.58812
# 33/33 [==============================] - 12s 376ms/step - loss: 0.3799 - accuracy: 0.8501 - val_loss: 2.7556 - val_accuracy: 0.3308 - lr: 0.0010
# Epoch 7/100
# 33/33 [==============================] - ETA: 0s - loss: 0.3187 - accuracy: 0.8878
# Epoch 7: val_loss did not improve from 1.58812
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 33/33 [==============================] - 12s 370ms/step - loss: 0.3187 - accuracy: 0.8878 - val_loss: 2.8513 - val_accuracy: 0.3308 - lr: 0.0010
# Epoch 8/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9304
# Epoch 8: val_loss did not improve from 1.58812
# 33/33 [==============================] - 12s 372ms/step - loss: 0.1967 - accuracy: 0.9304 - val_loss: 2.6156 - val_accuracy: 0.3308 - lr: 1.0000e-04
# Epoch 9/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1620 - accuracy: 0.9516
# Epoch 9: val_loss did not improve from 1.58812
# 33/33 [==============================] - 12s 372ms/step - loss: 0.1620 - accuracy: 0.9516 - val_loss: 2.6434 - val_accuracy: 0.3308 - lr: 1.0000e-04
# Epoch 10/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1573 - accuracy: 0.9410
# Epoch 10: val_loss did not improve from 1.58812
# 33/33 [==============================] - 12s 372ms/step - loss: 0.1573 - accuracy: 0.9410 - val_loss: 2.5536 - val_accuracy: 0.3383 - lr: 1.0000e-04
# Epoch 11/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1367 - accuracy: 0.9545
# Epoch 11: val_loss did not improve from 1.58812
# 33/33 [==============================] - 12s 373ms/step - loss: 0.1367 - accuracy: 0.9545 - val_loss: 2.3051 - val_accuracy: 0.3534 - lr: 1.0000e-04
# Epoch 12/100
# 33/33 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.9603
# Epoch 12: val_loss did not improve from 1.58812
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 33/33 [==============================] - 12s 377ms/step - loss: 0.1250 - accuracy: 0.9603 - val_loss: 2.1012 - val_accuracy: 0.3684 - lr: 1.0000e-04

# %% [markdown]
# # Homework 4 : ChatGPT(Transfer Learning - ResNet50) - 1.0987
# 다음 코드의 CNN 을 Transfer learning 으로 바꿔 줘
# 단, 모델은 VGG16 이외의 모델을 써 줘

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.applications import ResNet50

# Use this constant wherever necessary
IMG_SIZE = 300

# This function normalizes and resizes the images.

# COMPLETE THE CODE IN THIS FUNCTION
def preprocess(image, label):
    # RESIZE YOUR IMAGES HERE (HINT: After resizing the shape of the images
    # should be (300, 300, 3).
    # NORMALIZE YOUR IMAGES HERE (HINT: Rescale by 1/.255))
  
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.resize(image, size=(300, 300))
    return image, label


# COMPLETE THE CODE IN THIS FUNCTION.
def solution_model():
    # Loads and splits the data into training and validation splits using tfds.
    (ds_train, ds_validation), ds_info = tfds.load(
        name='beans',
        split=['train', 'validation'],
        as_supervised=True,
        with_info=True)
 
    BATCH_SIZE = 32 # YOUR CODE HERE

    # Resizes and normalizes train and validation datasets using the
    # preprocess() function.
    # Also makes other calls, as evident from the code, to prepare them for
    # training.
    ds_train = ds_train.map(preprocess).cache().shuffle(
        ds_info.splits['train'].num_examples).batch(BATCH_SIZE).prefetch(
        tf.data.experimental.AUTOTUNE)
    ds_validation = ds_validation.map(preprocess).batch(BATCH_SIZE).cache(

    ).prefetch(tf.data.experimental.AUTOTUNE)

    # Code to define the model
    transfer_model = ResNet50(include_top=False, input_shape=(300, 300, 3))
    for layer in transfer_model.layers:
        layer.trainable=False

    model = Sequential([
        transfer_model, 
        Flatten(), 
        # Layer 추가
        Flatten(), 
        Dense(64, activation='relu'), 
        Dropout(0.2),
        Dense(32, activation='relu'), 
        Dense(3, activation='softmax'),
    ])

    # Code to compile and train the model
    model.compile(
        # YOUR CODE HERE
        loss = 'sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy']
    )
       
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    checkpoint_path = "checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path,
        save_weights_only=True,
        save_best_only = True,
        monitor='val_loss',
        verbose=1)
    
    model.fit(ds_train, 
            validation_data=(ds_validation),
            epochs=100, 
            callbacks=[checkpoint, early_stopping])
    model.load_weights(checkpoint_path)                      

    return model


# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, your saved .h5 model will
# be sent to the testing infrastructure for scoring
# and the score will be returned to you.
if __name__ == '__main__':
    model = solution_model()
    model.save("beans-ResNet50.h5")
# Out:
# Epoch 1/100
# 33/33 [==============================] - ETA: 0s - loss: 6.6378 - accuracy: 0.3443
# Epoch 1: val_loss improved from inf to 1.11358, saving model to checkpoint.ckpt
# 33/33 [==============================] - 18s 277ms/step - loss: 6.6378 - accuracy: 0.3443 - val_loss: 1.1136 - val_accuracy: 0.3308
# Epoch 2/100
# 33/33 [==============================] - ETA: 0s - loss: 1.1063 - accuracy: 0.3230
# Epoch 2: val_loss improved from 1.11358 to 1.09865, saving model to checkpoint.ckpt
# 33/33 [==============================] - 8s 230ms/step - loss: 1.1063 - accuracy: 0.3230 - val_loss: 1.0986 - val_accuracy: 0.3308
# Epoch 3/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3298
# Epoch 3: val_loss improved from 1.09865 to 1.09863, saving model to checkpoint.ckpt
# 33/33 [==============================] - 8s 232ms/step - loss: 1.0987 - accuracy: 0.3298 - val_loss: 1.0986 - val_accuracy: 0.3308
# Epoch 4/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3298
# Epoch 4: val_loss improved from 1.09863 to 1.09861, saving model to checkpoint.ckpt
# 33/33 [==============================] - 8s 250ms/step - loss: 1.0987 - accuracy: 0.3298 - val_loss: 1.0986 - val_accuracy: 0.3308
# Epoch 5/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3337
# Epoch 5: val_loss improved from 1.09861 to 1.09860, saving model to checkpoint.ckpt
# 33/33 [==============================] - 7s 225ms/step - loss: 1.0987 - accuracy: 0.3337 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 6/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3143
# Epoch 6: val_loss improved from 1.09860 to 1.09859, saving model to checkpoint.ckpt
# 33/33 [==============================] - 8s 232ms/step - loss: 1.0987 - accuracy: 0.3143 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 7/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 7: val_loss improved from 1.09859 to 1.09857, saving model to checkpoint.ckpt
# 33/33 [==============================] - 8s 248ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 8/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3201
# Epoch 8: val_loss did not improve from 1.09857
# 33/33 [==============================] - 6s 191ms/step - loss: 1.0987 - accuracy: 0.3201 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 9/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 9: val_loss did not improve from 1.09857
# 33/33 [==============================] - 6s 195ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 10/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 10: val_loss improved from 1.09857 to 1.09857, saving model to checkpoint.ckpt
# 33/33 [==============================] - 8s 249ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 11/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.3366
# Epoch 11: val_loss did not improve from 1.09857
# 33/33 [==============================] - 6s 192ms/step - loss: 1.0986 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 12/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 12: val_loss did not improve from 1.09857
# 33/33 [==============================] - 7s 203ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 13/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 13: val_loss did not improve from 1.09857
# 33/33 [==============================] - 7s 213ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 14/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 14: val_loss did not improve from 1.09857
# 33/33 [==============================] - 6s 194ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 15/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 15: val_loss did not improve from 1.09857
# 33/33 [==============================] - 6s 197ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 16/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.3366
# Epoch 16: val_loss improved from 1.09857 to 1.09856, saving model to checkpoint.ckpt
# 33/33 [==============================] - 8s 231ms/step - loss: 1.0986 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 17/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 17: val_loss did not improve from 1.09856
# 33/33 [==============================] - 7s 196ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 18/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0988 - accuracy: 0.3366
# Epoch 18: val_loss did not improve from 1.09856
# 33/33 [==============================] - 6s 197ms/step - loss: 1.0988 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 19/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.3366
# Epoch 19: val_loss did not improve from 1.09856
# 33/33 [==============================] - 6s 193ms/step - loss: 1.0986 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 20/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 20: val_loss did not improve from 1.09856
# 33/33 [==============================] - 7s 199ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 21/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.3366
# Epoch 21: val_loss did not improve from 1.09856
# 33/33 [==============================] - 6s 192ms/step - loss: 1.0986 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 22/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.3366
# Epoch 22: val_loss did not improve from 1.09856
# 33/33 [==============================] - 7s 201ms/step - loss: 1.0986 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 23/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0988 - accuracy: 0.3366
# Epoch 23: val_loss improved from 1.09856 to 1.09856, saving model to checkpoint.ckpt
# 33/33 [==============================] - 8s 231ms/step - loss: 1.0988 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 24/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.3366
# Epoch 24: val_loss did not improve from 1.09856
# 33/33 [==============================] - 6s 192ms/step - loss: 1.0986 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 25/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.3366
# Epoch 25: val_loss did not improve from 1.09856
# 33/33 [==============================] - 7s 196ms/step - loss: 1.0986 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 26/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 26: val_loss did not improve from 1.09856
# 33/33 [==============================] - 7s 199ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 27/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.3211
# Epoch 27: val_loss did not improve from 1.09856
# 33/33 [==============================] - 7s 199ms/step - loss: 1.0986 - accuracy: 0.3211 - val_loss: 1.0986 - val_accuracy: 0.3308
# Epoch 28/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.3279
# Epoch 28: val_loss did not improve from 1.09856
# 33/33 [==============================] - 6s 195ms/step - loss: 1.0986 - accuracy: 0.3279 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 29/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.3366
# Epoch 29: val_loss did not improve from 1.09856
# 33/33 [==============================] - 6s 196ms/step - loss: 1.0986 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 30/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 30: val_loss did not improve from 1.09856
# 33/33 [==============================] - 7s 215ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 31/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.3366
# Epoch 31: val_loss did not improve from 1.09856
# 33/33 [==============================] - 7s 216ms/step - loss: 1.0986 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 32/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 32: val_loss did not improve from 1.09856
# 33/33 [==============================] - 7s 205ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 33/100
# 33/33 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.3366
# Epoch 33: val_loss did not improve from 1.09856
# 33/33 [==============================] - 6s 194ms/step - loss: 1.0987 - accuracy: 0.3366 - val_loss: 1.0986 - val_accuracy: 0.3383
