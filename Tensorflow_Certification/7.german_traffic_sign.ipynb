# %% [markdown]
# <a href="https://colab.research.google.com/github/Judy-Choi/Tensorflow_Certificate/blob/main/7.german_traffic_sign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Goal Metric
# - val_loss : 0.5
# - val_acc : -

# %% [markdown]
# # 정답 - 0.03009

# %%
# German Traffic Sign
# https://www.kaggle.com/datasets/meowmeowmeowmeowmeow/gtsrb-german-traffic-sign
import urllib
import zipfile
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Reshape, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
def download_and_extract_data():
    url = "https://storage.googleapis.com/download.tensorflow.org/data/certificate/germantrafficsigns.zip"
    urllib.request.urlretrieve(url, 'germantrafficsigns.zip')

    with zipfile.ZipFile('germantrafficsigns.zip','r') as zip_ref:
        zip_ref.extractall()

# COMPLETE THE CODE IN THIS FUNCTION
def preprocess(image, label):
  # NORMALIZE YOUR IMAGES HERE (HINT: Rescale by 1/.255)
    image /= 255
    return image, label
# This function loads the data, normalizes and resizes the images, splits it into
# train and validation sets, defines the model, compiles it and finally
# trains the model. The trained model is returned from this function.
# COMPLETE THE CODE IN THIS FUNCTION.

# %%
def solution_model():
  # Downloads and extracts the dataset to the directory that
  # contains this file.
    download_and_extract_data()
    BATCH_SIZE = 32
    IMG_SIZE = 30
  # The following code reads the training and validation data from their
  # respective directories, resizes them into the specified image size
  # and splits them into batches. You must fill in the image_size
  # argument for both training and validation data.
  # HINT: Image size is a tuple
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
	directory='train/',
	label_mode='categorical',
	image_size=(IMG_SIZE, IMG_SIZE),
	batch_size=BATCH_SIZE)
    
    val_ds = tf.keras.preprocessing.image_dataset_from_directory (
 	directory='validation/',
	label_mode='categorical',
	image_size=(IMG_SIZE, IMG_SIZE),
	batch_size=BATCH_SIZE)
    
  # Normalizes train and validation datasets using the
  # preprocess() function.
  # Also makes other calls, as evident from the code, to prepare them for
  # training.
  # Do not batch or resize the images in the dataset here since it’s already
  # been done previously.
    train_ds = train_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE).prefetch(
        tf.data.experimental.AUTOTUNE)
    val_ds = val_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)
  # Code to define the model
    model = tf.keras.models.Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dropout(0.25),
        Dense(128, activation='relu'),
        Dense(43, activation='softmax')
    ])
  # Code to compile and train the model
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['acc']
    )

    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    checkpoint_path = 'checkpoint.ckpt'
    checkpoint = ModelCheckpoint(checkpoint_path,
                 save_weights_only=True,
                 save_best_only=True,
                 monitor='val_loss',
                 verbose=1)
    model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=50,
        callbacks=[checkpoint, early_stopping]
    )
    model.load_weights(checkpoint_path)
    return model

# %%
# Note that you’ll need to save your model as a .h5 like this.
# When you press the Submit and Test button, your saved .h5 model will
# be sent to the testing infrastructure for scoring
# and the score will be returned to you.

if __name__ == '__main__':
    model = solution_model()
    model.save('GermanTrafficSign-cnn.h5')
# Out:
# Found 31367 files belonging to 43 classes.
# Found 7842 files belonging to 43 classes.
# Epoch 1/50
# 981/981 [==============================] - ETA: 0s - loss: 1.8618 - acc: 0.4694
# Epoch 1: val_loss improved from inf to 0.49340, saving model to checkpoint.ckpt
# 981/981 [==============================] - 22s 11ms/step - loss: 1.8618 - acc: 0.4694 - val_loss: 0.4934 - val_acc: 0.8549
# Epoch 2/50
# 981/981 [==============================] - ETA: 0s - loss: 0.4254 - acc: 0.8692
# Epoch 2: val_loss improved from 0.49340 to 0.18565, saving model to checkpoint.ckpt
# 981/981 [==============================] - 10s 10ms/step - loss: 0.4254 - acc: 0.8692 - val_loss: 0.1857 - val_acc: 0.9484
# Epoch 3/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.2319 - acc: 0.9287
# Epoch 3: val_loss improved from 0.18565 to 0.10696, saving model to checkpoint.ckpt
# 981/981 [==============================] - 8s 9ms/step - loss: 0.2316 - acc: 0.9289 - val_loss: 0.1070 - val_acc: 0.9709
# Epoch 4/50
# 977/981 [============================>.] - ETA: 0s - loss: 0.1591 - acc: 0.9510
# Epoch 4: val_loss improved from 0.10696 to 0.09098, saving model to checkpoint.ckpt
# 981/981 [==============================] - 9s 10ms/step - loss: 0.1589 - acc: 0.9510 - val_loss: 0.0910 - val_acc: 0.9754
# Epoch 5/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.1317 - acc: 0.9595
# Epoch 5: val_loss did not improve from 0.09098
# 981/981 [==============================] - 9s 9ms/step - loss: 0.1316 - acc: 0.9595 - val_loss: 0.0980 - val_acc: 0.9722
# Epoch 6/50
# 973/981 [============================>.] - ETA: 0s - loss: 0.1023 - acc: 0.9690
# Epoch 6: val_loss improved from 0.09098 to 0.06752, saving model to checkpoint.ckpt
# 981/981 [==============================] - 9s 10ms/step - loss: 0.1022 - acc: 0.9690 - val_loss: 0.0675 - val_acc: 0.9830
# Epoch 7/50
# 979/981 [============================>.] - ETA: 0s - loss: 0.0901 - acc: 0.9722
# Epoch 7: val_loss improved from 0.06752 to 0.06374, saving model to checkpoint.ckpt
# 981/981 [==============================] - 8s 9ms/step - loss: 0.0900 - acc: 0.9722 - val_loss: 0.0637 - val_acc: 0.9834
# Epoch 8/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0767 - acc: 0.9769
# Epoch 8: val_loss did not improve from 0.06374
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0766 - acc: 0.9770 - val_loss: 0.0660 - val_acc: 0.9811
# Epoch 9/50
# 972/981 [============================>.] - ETA: 0s - loss: 0.0707 - acc: 0.9777
# Epoch 9: val_loss improved from 0.06374 to 0.04412, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0705 - acc: 0.9777 - val_loss: 0.0441 - val_acc: 0.9899
# Epoch 10/50
# 973/981 [============================>.] - ETA: 0s - loss: 0.0669 - acc: 0.9802
# Epoch 10: val_loss did not improve from 0.04412
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0668 - acc: 0.9802 - val_loss: 0.0461 - val_acc: 0.9883
# Epoch 11/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0578 - acc: 0.9812
# Epoch 11: val_loss improved from 0.04412 to 0.03902, saving model to checkpoint.ckpt
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0581 - acc: 0.9810 - val_loss: 0.0390 - val_acc: 0.9904
# Epoch 12/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.0633 - acc: 0.9803
# Epoch 12: val_loss did not improve from 0.03902
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0632 - acc: 0.9803 - val_loss: 0.0457 - val_acc: 0.9888
# Epoch 13/50
# 972/981 [============================>.] - ETA: 0s - loss: 0.0525 - acc: 0.9831
# Epoch 13: val_loss did not improve from 0.03902
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0523 - acc: 0.9832 - val_loss: 0.0420 - val_acc: 0.9889
# Epoch 14/50
# 974/981 [============================>.] - ETA: 0s - loss: 0.0493 - acc: 0.9843
# Epoch 14: val_loss improved from 0.03902 to 0.03792, saving model to checkpoint.ckpt
# 981/981 [==============================] - 9s 10ms/step - loss: 0.0495 - acc: 0.9842 - val_loss: 0.0379 - val_acc: 0.9901
# Epoch 15/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.0440 - acc: 0.9871
# Epoch 15: val_loss did not improve from 0.03792
# 981/981 [==============================] - 13s 13ms/step - loss: 0.0440 - acc: 0.9871 - val_loss: 0.0388 - val_acc: 0.9901
# Epoch 16/50
# 970/981 [============================>.] - ETA: 0s - loss: 0.0424 - acc: 0.9869
# Epoch 16: val_loss did not improve from 0.03792
# 981/981 [==============================] - 9s 10ms/step - loss: 0.0422 - acc: 0.9869 - val_loss: 0.0415 - val_acc: 0.9878
# Epoch 17/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0440 - acc: 0.9867
# Epoch 17: val_loss improved from 0.03792 to 0.03701, saving model to checkpoint.ckpt
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0440 - acc: 0.9867 - val_loss: 0.0370 - val_acc: 0.9909
# Epoch 18/50
# 977/981 [============================>.] - ETA: 0s - loss: 0.0398 - acc: 0.9879
# Epoch 18: val_loss did not improve from 0.03701
# 981/981 [==============================] - 12s 12ms/step - loss: 0.0397 - acc: 0.9879 - val_loss: 0.0444 - val_acc: 0.9887
# Epoch 19/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.0451 - acc: 0.9866
# Epoch 19: val_loss did not improve from 0.03701
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0450 - acc: 0.9866 - val_loss: 0.0422 - val_acc: 0.9899
# Epoch 20/50
# 969/981 [============================>.] - ETA: 0s - loss: 0.0361 - acc: 0.9890
# Epoch 20: val_loss improved from 0.03701 to 0.03116, saving model to checkpoint.ckpt
# 981/981 [==============================] - 9s 10ms/step - loss: 0.0359 - acc: 0.9891 - val_loss: 0.0312 - val_acc: 0.9927
# Epoch 21/50
# 970/981 [============================>.] - ETA: 0s - loss: 0.0313 - acc: 0.9903
# Epoch 21: val_loss did not improve from 0.03116
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0315 - acc: 0.9902 - val_loss: 0.0351 - val_acc: 0.9918
# Epoch 22/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0408 - acc: 0.9877
# Epoch 22: val_loss did not improve from 0.03116
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0409 - acc: 0.9877 - val_loss: 0.0373 - val_acc: 0.9906
# Epoch 23/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.0333 - acc: 0.9890
# Epoch 23: val_loss improved from 0.03116 to 0.03009, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0333 - acc: 0.9890 - val_loss: 0.0301 - val_acc: 0.9922
# Epoch 24/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0389 - acc: 0.9883
# Epoch 24: val_loss did not improve from 0.03009
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0387 - acc: 0.9883 - val_loss: 0.0326 - val_acc: 0.9927
# Epoch 25/50
# 981/981 [==============================] - ETA: 0s - loss: 0.0290 - acc: 0.9911
# Epoch 25: val_loss did not improve from 0.03009
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0290 - acc: 0.9911 - val_loss: 0.0413 - val_acc: 0.9898
# Epoch 26/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.0293 - acc: 0.9902
# Epoch 26: val_loss did not improve from 0.03009
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0293 - acc: 0.9902 - val_loss: 0.0351 - val_acc: 0.9920
# Epoch 27/50
# 981/981 [==============================] - ETA: 0s - loss: 0.0370 - acc: 0.9890
# Epoch 27: val_loss did not improve from 0.03009
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0370 - acc: 0.9890 - val_loss: 0.0332 - val_acc: 0.9904
# Epoch 28/50
# 975/981 [============================>.] - ETA: 0s - loss: 0.0340 - acc: 0.9900
# Epoch 28: val_loss did not improve from 0.03009
# 981/981 [==============================] - 9s 10ms/step - loss: 0.0339 - acc: 0.9900 - val_loss: 0.0401 - val_acc: 0.9902
# Epoch 29/50
# 972/981 [============================>.] - ETA: 0s - loss: 0.0341 - acc: 0.9902
# Epoch 29: val_loss did not improve from 0.03009
# 981/981 [==============================] - 9s 10ms/step - loss: 0.0342 - acc: 0.9902 - val_loss: 0.0302 - val_acc: 0.9909
# Epoch 30/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0296 - acc: 0.9913
# Epoch 30: val_loss did not improve from 0.03009
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0298 - acc: 0.9912 - val_loss: 0.0344 - val_acc: 0.9918
# Epoch 31/50
# 975/981 [============================>.] - ETA: 0s - loss: 0.0236 - acc: 0.9923
# Epoch 31: val_loss did not improve from 0.03009
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0235 - acc: 0.9923 - val_loss: 0.0387 - val_acc: 0.9913
# Epoch 32/50
# 981/981 [==============================] - ETA: 0s - loss: 0.0292 - acc: 0.9914
# Epoch 32: val_loss did not improve from 0.03009
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0292 - acc: 0.9914 - val_loss: 0.0341 - val_acc: 0.9925
# Epoch 33/50
# 970/981 [============================>.] - ETA: 0s - loss: 0.0314 - acc: 0.9908
# Epoch 33: val_loss did not improve from 0.03009
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0312 - acc: 0.9909 - val_loss: 0.0367 - val_acc: 0.9912

# %% [markdown]
# # Homework 1 : 직접 코딩 (CNN) - 0.02233

# %%
def solution_model():
  # Downloads and extracts the dataset to the directory that
  # contains this file.
    download_and_extract_data()
    BATCH_SIZE = 32
    IMG_SIZE = 30
  # The following code reads the training and validation data from their
  # respective directories, resizes them into the specified image size
  # and splits them into batches. You must fill in the image_size
  # argument for both training and validation data.
  # HINT: Image size is a tuple
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
	directory='train/',
	label_mode='categorical',
	image_size=(IMG_SIZE, IMG_SIZE),
	batch_size=BATCH_SIZE)
    
    val_ds = tf.keras.preprocessing.image_dataset_from_directory (
 	directory='validation/',
	label_mode='categorical',
	image_size=(IMG_SIZE, IMG_SIZE),
	batch_size=BATCH_SIZE)
    
  # Normalizes train and validation datasets using the
  # preprocess() function.
  # Also makes other calls, as evident from the code, to prepare them for
  # training.
  # Do not batch or resize the images in the dataset here since it’s already
  # been done previously.
    train_ds = train_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE).prefetch(
        tf.data.experimental.AUTOTUNE)
    val_ds = val_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)
  # Code to define the model
    model = tf.keras.models.Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        # 64 -> 128
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dropout(0.25),
        Dense(128, activation='relu'),
        Dense(43, activation='softmax')
    ])
  # Code to compile and train the model
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['acc']
    )

    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    checkpoint_path = 'checkpoint.ckpt'
    checkpoint = ModelCheckpoint(checkpoint_path,
                 save_weights_only=True,
                 save_best_only=True,
                 monitor='val_loss',
                 verbose=1)
    model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=50,
        callbacks=[checkpoint, early_stopping]
    )
    model.load_weights(checkpoint_path)
    return model

if __name__ == '__main__':
    model = solution_model()
    model.save('(HW)GermanTrafficSign-cnn.h5')
# Out:
# Found 31367 files belonging to 43 classes.
# Found 7842 files belonging to 43 classes.
# Epoch 1/50
# 981/981 [==============================] - ETA: 0s - loss: 1.4818 - acc: 0.5809
# Epoch 1: val_loss improved from inf to 0.35319, saving model to checkpoint.ckpt
# 981/981 [==============================] - 23s 12ms/step - loss: 1.4818 - acc: 0.5809 - val_loss: 0.3532 - val_acc: 0.9166
# Epoch 2/50
# 973/981 [============================>.] - ETA: 0s - loss: 0.2815 - acc: 0.9154
# Epoch 2: val_loss improved from 0.35319 to 0.13056, saving model to checkpoint.ckpt
# 981/981 [==============================] - 12s 13ms/step - loss: 0.2807 - acc: 0.9157 - val_loss: 0.1306 - val_acc: 0.9645
# Epoch 3/50
# 974/981 [============================>.] - ETA: 0s - loss: 0.1431 - acc: 0.9562
# Epoch 3: val_loss improved from 0.13056 to 0.07697, saving model to checkpoint.ckpt
# 981/981 [==============================] - 10s 10ms/step - loss: 0.1427 - acc: 0.9563 - val_loss: 0.0770 - val_acc: 0.9774
# Epoch 4/50
# 977/981 [============================>.] - ETA: 0s - loss: 0.1010 - acc: 0.9692
# Epoch 4: val_loss improved from 0.07697 to 0.07525, saving model to checkpoint.ckpt
# 981/981 [==============================] - 10s 10ms/step - loss: 0.1011 - acc: 0.9691 - val_loss: 0.0753 - val_acc: 0.9787
# Epoch 5/50
# 972/981 [============================>.] - ETA: 0s - loss: 0.0803 - acc: 0.9751
# Epoch 5: val_loss improved from 0.07525 to 0.06488, saving model to checkpoint.ckpt
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0802 - acc: 0.9752 - val_loss: 0.0649 - val_acc: 0.9815
# Epoch 6/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.0685 - acc: 0.9789
# Epoch 6: val_loss improved from 0.06488 to 0.05462, saving model to checkpoint.ckpt
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0684 - acc: 0.9789 - val_loss: 0.0546 - val_acc: 0.9841
# Epoch 7/50
# 974/981 [============================>.] - ETA: 0s - loss: 0.0577 - acc: 0.9814
# Epoch 7: val_loss improved from 0.05462 to 0.04475, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0575 - acc: 0.9814 - val_loss: 0.0448 - val_acc: 0.9880
# Epoch 8/50
# 973/981 [============================>.] - ETA: 0s - loss: 0.0485 - acc: 0.9845
# Epoch 8: val_loss did not improve from 0.04475
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0483 - acc: 0.9845 - val_loss: 0.0451 - val_acc: 0.9874
# Epoch 9/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.0402 - acc: 0.9875
# Epoch 9: val_loss did not improve from 0.04475
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0404 - acc: 0.9875 - val_loss: 0.0651 - val_acc: 0.9816
# Epoch 10/50
# 973/981 [============================>.] - ETA: 0s - loss: 0.0416 - acc: 0.9868
# Epoch 10: val_loss improved from 0.04475 to 0.04308, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0416 - acc: 0.9868 - val_loss: 0.0431 - val_acc: 0.9889
# Epoch 11/50
# 972/981 [============================>.] - ETA: 0s - loss: 0.0341 - acc: 0.9888
# Epoch 11: val_loss improved from 0.04308 to 0.03435, saving model to checkpoint.ckpt
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0341 - acc: 0.9889 - val_loss: 0.0344 - val_acc: 0.9917
# Epoch 12/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.0346 - acc: 0.9890
# Epoch 12: val_loss did not improve from 0.03435
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0346 - acc: 0.9890 - val_loss: 0.0347 - val_acc: 0.9908
# Epoch 13/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.0308 - acc: 0.9904
# Epoch 13: val_loss did not improve from 0.03435
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0308 - acc: 0.9904 - val_loss: 0.0578 - val_acc: 0.9871
# Epoch 14/50
# 977/981 [============================>.] - ETA: 0s - loss: 0.0270 - acc: 0.9918
# Epoch 14: val_loss did not improve from 0.03435
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0270 - acc: 0.9917 - val_loss: 0.0935 - val_acc: 0.9824
# Epoch 15/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0298 - acc: 0.9909
# Epoch 15: val_loss did not improve from 0.03435
# 981/981 [==============================] - 10s 11ms/step - loss: 0.0300 - acc: 0.9908 - val_loss: 0.0384 - val_acc: 0.9909
# Epoch 16/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0275 - acc: 0.9909
# Epoch 16: val_loss did not improve from 0.03435
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0273 - acc: 0.9909 - val_loss: 0.0364 - val_acc: 0.9899
# Epoch 17/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0235 - acc: 0.9921
# Epoch 17: val_loss improved from 0.03435 to 0.03211, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0234 - acc: 0.9921 - val_loss: 0.0321 - val_acc: 0.9927
# Epoch 18/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0223 - acc: 0.9930
# Epoch 18: val_loss improved from 0.03211 to 0.03002, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0222 - acc: 0.9930 - val_loss: 0.0300 - val_acc: 0.9929
# Epoch 19/50
# 970/981 [============================>.] - ETA: 0s - loss: 0.0224 - acc: 0.9936
# Epoch 19: val_loss did not improve from 0.03002
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0223 - acc: 0.9937 - val_loss: 0.0436 - val_acc: 0.9907
# Epoch 20/50
# 974/981 [============================>.] - ETA: 0s - loss: 0.0281 - acc: 0.9915
# Epoch 20: val_loss did not improve from 0.03002
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0280 - acc: 0.9915 - val_loss: 0.0324 - val_acc: 0.9930
# Epoch 21/50
# 977/981 [============================>.] - ETA: 0s - loss: 0.0221 - acc: 0.9935
# Epoch 21: val_loss did not improve from 0.03002
# 981/981 [==============================] - 10s 11ms/step - loss: 0.0221 - acc: 0.9935 - val_loss: 0.0475 - val_acc: 0.9902
# Epoch 22/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0254 - acc: 0.9926
# Epoch 22: val_loss improved from 0.03002 to 0.02991, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0253 - acc: 0.9926 - val_loss: 0.0299 - val_acc: 0.9941
# Epoch 23/50
# 973/981 [============================>.] - ETA: 0s - loss: 0.0190 - acc: 0.9945
# Epoch 23: val_loss did not improve from 0.02991
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0191 - acc: 0.9945 - val_loss: 0.0355 - val_acc: 0.9902
# Epoch 24/50
# 981/981 [==============================] - ETA: 0s - loss: 0.0198 - acc: 0.9938
# Epoch 24: val_loss improved from 0.02991 to 0.02790, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0198 - acc: 0.9938 - val_loss: 0.0279 - val_acc: 0.9934
# Epoch 25/50
# 977/981 [============================>.] - ETA: 0s - loss: 0.0212 - acc: 0.9933
# Epoch 25: val_loss did not improve from 0.02790
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0213 - acc: 0.9933 - val_loss: 0.0393 - val_acc: 0.9911
# Epoch 26/50
# 979/981 [============================>.] - ETA: 0s - loss: 0.0223 - acc: 0.9933
# Epoch 26: val_loss did not improve from 0.02790
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0223 - acc: 0.9933 - val_loss: 0.0311 - val_acc: 0.9929
# Epoch 27/50
# 974/981 [============================>.] - ETA: 0s - loss: 0.0178 - acc: 0.9941
# Epoch 27: val_loss did not improve from 0.02790
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0177 - acc: 0.9942 - val_loss: 0.0404 - val_acc: 0.9916
# Epoch 28/50
# 980/981 [============================>.] - ETA: 0s - loss: 0.0204 - acc: 0.9941
# Epoch 28: val_loss did not improve from 0.02790
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0204 - acc: 0.9941 - val_loss: 0.0319 - val_acc: 0.9939
# Epoch 29/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0217 - acc: 0.9935
# Epoch 29: val_loss did not improve from 0.02790
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0220 - acc: 0.9935 - val_loss: 0.0300 - val_acc: 0.9936
# Epoch 30/50
# 974/981 [============================>.] - ETA: 0s - loss: 0.0161 - acc: 0.9959
# Epoch 30: val_loss improved from 0.02790 to 0.02782, saving model to checkpoint.ckpt
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0160 - acc: 0.9959 - val_loss: 0.0278 - val_acc: 0.9929
# Epoch 31/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0256 - acc: 0.9932
# Epoch 31: val_loss did not improve from 0.02782
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0254 - acc: 0.9932 - val_loss: 0.0400 - val_acc: 0.9909
# Epoch 32/50
# 971/981 [============================>.] - ETA: 0s - loss: 0.0151 - acc: 0.9959
# Epoch 32: val_loss improved from 0.02782 to 0.02237, saving model to checkpoint.ckpt
# 981/981 [==============================] - 12s 12ms/step - loss: 0.0149 - acc: 0.9960 - val_loss: 0.0224 - val_acc: 0.9941
# Epoch 33/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.0217 - acc: 0.9937
# Epoch 33: val_loss did not improve from 0.02237
# 981/981 [==============================] - 10s 10ms/step - loss: 0.
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0186 - acc: 0.9953 - val_loss: 0.0386 - val_acc: 0.9926
# Epoch 48/50
# 980/981 [============================>.] - ETA: 0s - loss: 0.0157 - acc: 0.9958
# Epoch 48: val_loss did not improve from 0.02233
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0157 - acc: 0.9958 - val_loss: 0.0267 - val_acc: 0.9944

# %% [markdown]
# # Homework 2 : 직접 코딩 (Transfer Learning - VGG16) - 0.19407

# %%
from tensorflow.keras.applications import VGG16

def solution_model():
  # Downloads and extracts the dataset to the directory that
  # contains this file.
    download_and_extract_data()
    BATCH_SIZE = 32
    IMG_SIZE = 224 # VGG16의 입력 이미지 크기

  # The following code reads the training and validation data from their
  # respective directories, resizes them into the specified image size
  # and splits them into batches. You must fill in the image_size
  # argument for both training and validation data.
  # HINT: Image size is a tuple
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
	directory='train/',
	label_mode='categorical',
	image_size=(IMG_SIZE, IMG_SIZE),
	batch_size=BATCH_SIZE)
    
    val_ds = tf.keras.preprocessing.image_dataset_from_directory (
 	directory='validation/',
	label_mode='categorical',
	image_size=(IMG_SIZE, IMG_SIZE),
	batch_size=BATCH_SIZE)
    
  # Normalizes train and validation datasets using the
  # preprocess() function.
  # Also makes other calls, as evident from the code, to prepare them for
  # training.
  # Do not batch or resize the images in the dataset here since it’s already
  # been done previously.
    train_ds = train_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE).prefetch(
        tf.data.experimental.AUTOTUNE)
    val_ds = val_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)
  
  # Code to define the model

    transfer_model = VGG16(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
    transfer_model.trainable=False

    model = Sequential([
        transfer_model, 
        Flatten(),
        Dropout(0.25),
        Dense(128, activation='relu'),
        Dense(43, activation='softmax')
    ])

  # Code to compile and train the model
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['acc']
    )

    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    checkpoint_path = 'checkpoint.ckpt'
    checkpoint = ModelCheckpoint(checkpoint_path,
                 save_weights_only=True,
                 save_best_only=True,
                 monitor='val_loss',
                 verbose=1)
    model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=50,
        callbacks=[checkpoint, early_stopping]
    )
    model.load_weights(checkpoint_path)
    return model

if __name__ == '__main__':
    model = solution_model()
    model.save('(HW)GermanTrafficSign-VGG16.h5')
# Out:
# Found 31367 files belonging to 43 classes.
# Found 7842 files belonging to 43 classes.
# Epoch 1/50
# 981/981 [==============================] - ETA: 0s - loss: 1.5104 - acc: 0.5867
# Epoch 1: val_loss improved from inf to 0.95717, saving model to checkpoint.ckpt
# 981/981 [==============================] - 167s 165ms/step - loss: 1.5104 - acc: 0.5867 - val_loss: 0.9572 - val_acc: 0.7354
# Epoch 2/50
# 980/981 [============================>.] - ETA: 0s - loss: 0.7808 - acc: 0.7726
# Epoch 2: val_loss improved from 0.95717 to 0.57633, saving model to checkpoint.ckpt
# 981/981 [==============================] - 159s 162ms/step - loss: 0.7808 - acc: 0.7727 - val_loss: 0.5763 - val_acc: 0.8276
# Epoch 3/50
# 981/981 [==============================] - ETA: 0s - loss: 0.5948 - acc: 0.8233
# Epoch 3: val_loss improved from 0.57633 to 0.54200, saving model to checkpoint.ckpt
# 981/981 [==============================] - 169s 172ms/step - loss: 0.5948 - acc: 0.8233 - val_loss: 0.5420 - val_acc: 0.8319
# Epoch 4/50
# 980/981 [============================>.] - ETA: 0s - loss: 0
50
# 980/981 [============================>.] - ETA: 0s - loss: 0.1828 - acc: 0.9425
# Epoch 40: val_loss did not improve from 0.19407
# 981/981 [==============================] - 159s 162ms/step - loss: 0.1830 - acc: 0.9425 - val_loss: 0.3834 - val_acc: 0.9018
# Epoch 41/50
# 980/981 [============================>.] - ETA: 0s - loss: 0.1700 - acc: 0.9438
# Epoch 41: val_loss did not improve from 0.19407
# 981/981 [==============================] - 169s 172ms/step - loss: 0.1700 - acc: 0.9438 - val_loss: 0.2822 - val_acc: 0.9235
# Epoch 42/50
# 980/981 [============================>.] - ETA: 0s - loss: 0.1688 - acc: 0.9467
# Epoch 42: val_loss did not improve from 0.19407
# 981/981 [==============================] - 169s 172ms/step - loss: 0.1688 - acc: 0.9467 - val_loss: 0.2911 - val_acc: 0.9217
# Epoch 43/50
# 981/981 [==============================] - ETA: 0s - loss: 0.1717 - acc: 0.9440
# Epoch 43: val_loss did not improve from 0.19407
# 981/981 [==============================] - 169s 172ms/step - loss: 0.1717 - acc: 0.9440 - val_loss: 0.3156 - val_acc: 0.9101

# %% [markdown]
# # Homework 3 : ChatGPT (CNN) - 0.01991
#
# 다음 코드를 최적화해 줘,
# 단, 다음 조건을 적용해 줘
# Use dropout
# Use batch normalization
# Use checkpoint with save best only, and save weight only and verbose = 1
# Use early stopping with patience = 10
# Use reduce learning rate on plateau
# set verbose = 1
# Set epochs = 50
# do not use data augmentation
# Use other methods to make val loss value lower.

# %%
def solution_model():
  # Downloads and extracts the dataset to the directory that
  # contains this file.
    download_and_extract_data()
    BATCH_SIZE = 32
    IMG_SIZE = 30
  # The following code reads the training and validation data from their
  # respective directories, resizes them into the specified image size
  # and splits them into batches. You must fill in the image_size
  # argument for both training and validation data.
  # HINT: Image size is a tuple
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
	directory='train/',
	label_mode='categorical',
	image_size=(IMG_SIZE, IMG_SIZE),
	batch_size=BATCH_SIZE)
    
    val_ds = tf.keras.preprocessing.image_dataset_from_directory (
 	directory='validation/',
	label_mode='categorical',
	image_size=(IMG_SIZE, IMG_SIZE),
	batch_size=BATCH_SIZE)
    
  # Normalizes train and validation datasets using the
  # preprocess() function.
  # Also makes other calls, as evident from the code, to prepare them for
  # training.
  # Do not batch or resize the images in the dataset here since it’s already
  # been done previously.
    train_ds = train_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE).prefetch(
        tf.data.experimental.AUTOTUNE)
    val_ds = val_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)
  # Code to define the model
    model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(43, activation='softmax')
])
  # Code to compile and train the model
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['acc']
    )

    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    checkpoint_path = 'checkpoint.ckpt'
    checkpoint = ModelCheckpoint(checkpoint_path,
                 save_weights_only=True,
                 save_best_only=True,
                 monitor='val_loss',
                 verbose=1)
    model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=50,
        callbacks=[checkpoint, early_stopping]
    )
    model.load_weights(checkpoint_path)
    return model

if __name__ == '__main__':
    model = solution_model()
    model.save('(ChatGPT)GermanTrafficSign-cnn.h5')
# Out:
# Found 31367 files belonging to 43 classes.
# Found 7842 files belonging to 43 classes.
# Epoch 1/50
# 975/981 [============================>.] - ETA: 0s - loss: 0.6706 - acc: 0.8206
# Epoch 1: val_loss improved from inf to 0.08128, saving model to checkpoint.ckpt
# 981/981 [==============================] - 14s 11ms/step - loss: 0.6682 - acc: 0.8212 - val_loss: 0.0813 - val_acc: 0.9779
# Epoch 2/50
# 981/981 [==============================] - ETA: 0s - loss: 0.0947 - acc: 0.9714
# Epoch 2: val_loss did not improve from 0.08128
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0947 - acc: 0.9714 - val_loss: 0.0976 - val_acc: 0.9695
# Epoch 3/50
# 977/981 [============================>.] - ETA: 0s - loss: 0.0669 - acc: 0.9798
# Epoch 3: val_loss improved from 0.08128 to 0.07262, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0667 - acc: 0.9798 - val_loss: 0.0726 - val_acc: 0.9774
# Epoch 4/50
# 977/981 [============================>.] - ETA: 0s - loss: 0.0544 - acc: 0.9833
# Epoch 4: val_loss improved from 0.07262 to 0.04244, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0543 - acc: 0.9834 - val_loss: 0.0424 - val_acc: 0.9875
# Epoch 5/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.0479 - acc: 0.9851
# Epoch 5: val_loss did not improve from 0.04244
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0481 - acc: 0.9850 - val_loss: 0.0545 - val_acc: 0.9847
# Epoch 6/50
# 975/981 [============================>.] - ETA: 0s - loss: 0.0448 - acc: 0.9859
# Epoch 6: val_loss did not improve from 0.04244
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0447 - acc: 0.9859 - val_loss: 0.0630 - val_acc: 0.9833
# Epoch 7/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.0497 - acc: 0.9852
# Epoch 7: val_loss improved from 0.04244 to 0.04197, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0496 - acc: 0.9853 - val_loss: 0.0420 - val_acc: 0.9879
# Epoch 8/50
# 981/981 [==============================] - ETA: 0s - loss: 0.0285 - acc: 0.9908
# Epoch 8: val_loss did not improve from 0.04197
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0285 - acc: 0.9908 - val_loss: 0.0473 - val_acc: 0.9864
# Epoch 9/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.0271 - acc: 0.9916
# Epoch 9: val_loss did not improve from 0.04197
# 981/981 [==============================] - 12s 12ms/step - loss: 0.0271 - acc: 0.9916 - val_loss: 0.1158 - val_acc: 0.9685
# Epoch 10/50
# 977/981 [============================>.] - ETA: 0s - loss: 0.0332 - acc: 0.9896
# Epoch 10: val_loss did not improve from 0.04197
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0332 - acc: 0.9896 - val_loss: 0.0798 - val_acc: 0.9759
# Epoch 11/50
# 975/981 [============================>.] - ETA: 0s - loss: 0.0282 - acc: 0.9912
# Epoch 11: val_loss improved from 0.04197 to 0.04154, saving model to checkpoint.ckpt
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0281 - acc: 0.9912 - val_loss: 0.0415 - val_acc: 0.9889
# Epoch 12/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.0226 - acc: 0.9934
# Epoch 12: val_loss did not improve from 0.04154
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0228 - acc: 0.9933 - val_loss: 0.0784 - val_acc: 0.9786
# Epoch 13/50
# 979/981 [============================>.] - ETA: 0s - loss: 0.0212 - acc: 0.9935
# Epoch 13: val_loss did not improve from 0.04154
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0215 - acc: 0.9935 - val_loss: 0.0461 - val_acc: 0.9880
# Epoch 14/50
# 972/981 [============================>.] - ETA: 0s - loss: 0.0196 - acc: 0.9940
# Epoch 14: val_loss improved from 0.04154 to 0.03966, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0199 - acc: 0.9939 - val_loss: 0.0397 - val_acc: 0.9889
# Epoch 15/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.0197 - acc: 0.9941
# Epoch 15: val_loss improved from 0.03966 to 0.03728, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0197 - acc: 0.9941 - val_loss: 0.0373 - val_acc: 0.9904
# Epoch 16/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.0185 - acc: 0.9943
# Epoch 16: val_loss improved from 0.03728 to 0.03174, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0185 - acc: 0.9944 - val_loss: 0.0317 - val_acc: 0.9927
# Epoch 17/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.0204 - acc: 0.9942
# Epoch 17: val_loss improved from 0.03174 to 0.01991, saving model to checkpoint.ckpt
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0204 - acc: 0.9942 - val_loss: 0.0199 - val_acc: 0.9940
# Epoch 18/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.0168 - acc: 0.9945
# Epoch 18: val_loss did not improve from 0.01991
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0168 - acc: 0.9945 - val_loss: 0.0222 - val_acc: 0.9948
# Epoch 19/50
# 979/981 [============================>.] - ETA: 0s - loss: 0.0156 - acc: 0.9950
# Epoch 19: val_loss did not improve from 0.01991
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0156 - acc: 0.9950 - val_loss: 0.0823 - val_acc: 0.9862
# Epoch 20/50
# 980/981 [============================>.] - ETA: 0s - loss: 0.0168 - acc: 0.9945
# Epoch 20: val_loss did not improve from 0.01991
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0168 - acc: 0.9945 - val_loss: 0.0255 - val_acc: 0.9935
# Epoch 21/50
# 978/981 [============================>.] - ETA: 0s - loss: 0.0128 - acc: 0.9960
# Epoch 21: val_loss did not improve from 0.01991
# 981/981 [==============================] - 10s 11ms/step - loss: 0.0128 - acc: 0.9960 - val_loss: 0.0336 - val_acc: 0.9912
# Epoch 22/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.0113 - acc: 0.9964
# Epoch 22: val_loss did not improve from 0.01991
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0113 - acc: 0.9965 - val_loss: 0.0252 - val_acc: 0.9930
# Epoch 23/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.0192 - acc: 0.9943
# Epoch 23: val_loss did not improve from 0.01991
# 981/981 [==============================] - 12s 12ms/step - loss: 0.0192 - acc: 0.9943 - val_loss: 0.0272 - val_acc: 0.9935
# Epoch 24/50
# 975/981 [============================>.] - ETA: 0s - loss: 0.0109 - acc: 0.9965
# Epoch 24: val_loss did not improve from 0.01991
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0109 - acc: 0.9965 - val_loss: 0.0237 - val_acc: 0.9948
# Epoch 25/50
# 981/981 [==============================] - ETA: 0s - loss: 0.0139 - acc: 0.9960
# Epoch 25: val_loss did not improve from 0.01991
# 981/981 [==============================] - 12s 12ms/step - loss: 0.0139 - acc: 0.9960 - val_loss: 0.0306 - val_acc: 0.9918
# Epoch 26/50
# 975/981 [============================>.] - ETA: 0s - loss: 0.0097 - acc: 0.9968
# Epoch 26: val_loss did not improve from 0.01991
# 981/981 [==============================] - 12s 12ms/step - loss: 0.0096 - acc: 0.9968 - val_loss: 0.0758 - val_acc: 0.9867
# Epoch 27/50
# 976/981 [============================>.] - ETA: 0s - loss: 0.0082 - acc: 0.9976
# Epoch 27: val_loss did not improve from 0.01991
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0082 - acc: 0.9976 - val_loss: 0.0477 - val_acc: 0.9888

# %% [markdown]
# # Homework 4 : ChatGPT (Transfer Learning - MobileNetV2) - 0.25376
#
# 다음 코드의 CNN 을 Transfer learning 으로 바꿔 줘
# 단, 모델은 VGG16 이외의 모델을 써 줘

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Reshape, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from tensorflow.keras.applications import MobileNetV2

def solution_model():
    # Downloads and extracts the dataset to the directory that
    # contains this file.
    download_and_extract_data()
    BATCH_SIZE = 32
    IMG_SIZE = 224  # MobileNetV2의 입력 이미지 크기

    # The following code reads the training and validation data from their
    # respective directories, resizes them into the specified image size
    # and splits them into batches. You must fill in the image_size
    # argument for both training and validation data.
    # HINT: Image size is a tuple
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        directory='train/',
        label_mode='categorical',
        image_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE)

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        directory='validation/',
        label_mode='categorical',
        image_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE)

    # Normalizes train and validation datasets using the
    # preprocess() function.
    # Also makes other calls, as evident from the code, to prepare them for
    # training.
    # Do not batch or resize the images in the dataset here since it’s already
    # been done previously.
    train_ds = train_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE).prefetch(
        tf.data.experimental.AUTOTUNE)
    val_ds = val_ds.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)

    # Code to define the model
    transfer_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
    transfer_model.trainable = False

    model = Sequential([
        transfer_model,
        GlobalAveragePooling2D(),
        Dropout(0.25),
        Dense(128, activation='relu'),
        Dense(43, activation='softmax')
    ])

    # Code to compile and train the model
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['acc']
    )

    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    checkpoint_path = 'checkpoint.ckpt'
    checkpoint = ModelCheckpoint(checkpoint_path,
                                  save_weights_only=True,
                                  save_best_only=True,
                                  monitor='val_loss',
                                  verbose=1)
    model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=50,
        callbacks=[checkpoint, early_stopping]
    )
    model.load_weights(checkpoint_path)
    return model

if __name__ == '__main__':
    model = solution_model()
    model.save('(HW)GermanTrafficSign-MobileNetV2.h5')
# Out:
# Found 31367 files belonging to 43 classes.
# Found 7842 files belonging to 43 classes.
# Epoch 1/50
# 981/981 [==============================] - ETA: 0s - loss: 1.2153 - acc: 0.6295
# Epoch 1: val_loss improved from inf to 0.69938, saving model to checkpoint.ckpt
# 981/981 [==============================] - 71s 68ms/step - loss: 1.2153 - acc: 0.6295 - val_loss: 0.6994 - val_acc: 0.7766
# Epoch 2/50
# 981/981 [==============================] - ETA: 0s - loss: 0.7074 - acc: 0.7701
# Epoch 2: val_loss improved from 0.69938 to 0.55690, saving model to checkpoint.ckpt
# 981/981 [==============================] - 65s 66ms/step - loss: 0.7074 - acc: 0.7701 - val_loss: 0.5569 - val_acc: 0.8226
# Epoch 3/50
# 980/981 [============================>.] - ETA: 0s - loss: 0.5885 - acc: 0.8059
# Epoch 3: val_loss improved from 0.55690 to 0.47297, saving model to checkpoint.ckpt
# 981/981 [==============================] - 65s 66ms/step - loss: 0.5885 - acc: 0.8059 - val_loss: 0.4730 - val_acc: 0.8423
# Epoch 4/50
# 980/981 [============================>.] - ETA: 0s - loss: 0.5170 - acc: 0.8282
# Epoch 4: val_loss improved from 0.47297 to 0.45742, saving model to checkpoint.ckpt
# 981/981 [==============================] - 65s 66ms/step - loss: 0.5170 - acc: 0.8282 - val_loss: 0.4574 - val_acc: 0.8504
# Epoch 5/50
# 981/981 [==============================] - ETA: 0s - loss: 0.4711 - acc: 0.8410
# Epoch 5: val_loss improved from 0.45742 to 0.40726, saving model to checkpoint.ckpt
# 981/981 [==============================] - 55s 56ms/step - loss: 0.4711 - acc: 0.8410 - val_loss: 0.4073 - val_acc: 0.8685
# Epoch 6/50
# 981/981 [==============================] - ETA: 0s - loss: 0.4348 - acc: 0.8526
# Epoch 6: val_loss improved from 0.40726 to 0.38255, saving model to checkpoint.ckpt
# 981/981 [==============================] - 55s 56ms/step - loss: 0.4348 - acc: 0.8526 - val_loss: 0.3826 - val_acc: 0.8734
# Epoch 7/50
# 981/981 [==============================] - ETA: 0s - loss: 0.4046 - acc: 0.8608
# Epoch 7: val_loss improved from 0.38255 to 0.36067, saving model to checkpoint.ckpt
# 981/981 [==============================] - 65s 66ms/step - loss: 0.4046 - acc: 0.8608 - val_loss: 0.3607 - val_acc: 0.8810
# Epoch 8/50
# 981/981 [==============================] - ETA: 0s - loss: 0.3847 - acc: 0.8687
# Epoch 8: val_loss improved from 0.36067 to 0.33828, saving model to checkpoint.ckpt
# 981/981 [==============================] - 64s 66ms/step - loss: 0.3847 - acc: 0.8687 - val_loss: 0.3383 - val_acc: 0.8903
# Epoch 9/50
# 981/981 [==============================] - ETA: 0s - loss: 0.3638 - acc: 0.8741
# Epoch 9: val_loss improved from 0.33828 to 0.33750, saving model to checkpoint.ckpt
# 981/981 [==============================] - 65s 66ms/step - loss: 0.3638 - acc: 0.8741 - val_loss: 0.3375 - val_acc: 0.8891
# Epoch 10/50
# 980/981 [============================>.] - ETA: 0s - loss: 0.3501 - acc: 0.8815
# Epoch 10: val_loss did not improve from 0.33750
# 981/981 [==============================] - 55s 55ms/step - loss: 0.3501 - acc: 0.8815 - val_loss: 0.3579 - val_acc: 0.8798
# Epoch 11/50
# 980/981 [============================>.] - ETA: 0s - loss: 0